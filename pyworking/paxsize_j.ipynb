# %%
import os
import pkg_resources

# %%
def calc_container(path):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(path):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            total_size += os.path.getsize(fp)
    return total_size

# %%
dists = [d for d in pkg_resources.working_set]

# %%
for dist in dists:
    try:
        path = os.path.join(dist.location, dist.project_name)
        size = calc_container(path)
        if size/1000 > 1.0:
            print (f"{dist}: {size/1000000} MB")
            print("-"*40)
    except OSError:
        '{} no longer exists'.format(dist.project_name)
# Out:
# zipp 3.16.2: 0.026202 MB
# ----------------------------------------
# xgboost 1.7.6: 100.070753 MB
# ----------------------------------------
# wrapt 1.15.0: 0.152912 MB
# ----------------------------------------
# widgetsnbextension 3.5.1: 4.610028 MB
# ----------------------------------------
# wheel 0.41.0: 0.354983 MB
# ----------------------------------------
# Werkzeug 2.2.3: 1.477819 MB
# ----------------------------------------
# webencodings 0.5.1: 0.054893 MB
# ----------------------------------------
# webcolors 1.13: 0.072012 MB
# ----------------------------------------
# wcwidth 0.2.5: 0.452367 MB
# ----------------------------------------
# urllib3 1.26.7: 0.679976 MB
# ----------------------------------------
# update 0.0.1: 0.002124 MB
# ----------------------------------------
# udemy 0.1.2: 0.011214 MB
# ----------------------------------------
# tzdata 2023.3: 0.505145 MB
# ----------------------------------------
# traitlets 5.9.0: 0.89747 MB
# ----------------------------------------
# tornado 6.3.2: 2.980692 MB
# ----------------------------------------
# tomli 2.0.1: 0.046331 MB
# ----------------------------------------
# tk 0.1.0: 0.011409 MB
# ----------------------------------------
# tinycss2 1.2.1: 0.14546 MB
# ----------------------------------------
# testpath 0.5.0: 0.183773 MB
# ----------------------------------------
# terminado 0.12.1: 0.060665 MB
# ----------------------------------------
# termcolor 2.2.0: 0.013957 MB
# ----------------------------------------
# tensorflow 2.11.0: 1024.626401 MB
# ----------------------------------------
# tensorboard 2.11.2: 11.593435 MB
# ----------------------------------------
# style 1.1.0: 0.009306 MB
# ----------------------------------------
# SQLAlchemy 2.0.19: 14.628658 MB
# ----------------------------------------
# soupsieve 2.4.1: 0.230142 MB
# ----------------------------------------
# sniffio 1.2.0: 0.009866 MB
# ----------------------------------------
# simplejson 3.17.5: 0.359223 MB
# ----------------------------------------
# setuptools 56.0.0: 3.005322 MB
# ----------------------------------------
# Send2Trash 1.8.0: 0.049188 MB
# ----------------------------------------
# seaborn 0.12.2: 1.80936 MB
# ----------------------------------------
# scipy 1.11.1: 106.951378 MB
# ----------------------------------------
# rsa 4.9: 0.160816 MB
# ----------------------------------------
# requests 2.31.0: 0.324849 MB
# ----------------------------------------
# referencing 0.30.1: 0.197478 MB
# ----------------------------------------
# Quandl 3.7.0: 0.111884 MB
# ----------------------------------------
# QtPy 1.11.2: 0.25147 MB
# ----------------------------------------
# qtconsole 5.1.1: 0.743398 MB
# ----------------------------------------
# pytz 2021.3: 0.975063 MB
# ----------------------------------------
# pyrsistent 0.18.0: 0.298911 MB
# ----------------------------------------
# Pygments 2.10.0: 6.211256 MB
# ----------------------------------------
# pycparser 2.20: 0.946194 MB
# ----------------------------------------
# pyasn1 0.4.8: 0.623258 MB
# ----------------------------------------
# psycopg2 2.9.3: 2.6784 MB
# ----------------------------------------
# platformdirs 3.10.0: 0.122055 MB
# ----------------------------------------
# pip 23.2.1: 11.391657 MB
# ----------------------------------------
# parso 0.8.2: 0.505866 MB
# ----------------------------------------
# pandas 2.0.3: 52.39761 MB
# ----------------------------------------
# packaging 23.1: 0.246022 MB
# ----------------------------------------
# overrides 7.3.1: 0.066511 MB
# ----------------------------------------
# oauthlib 3.2.2: 0.914443 MB
# ----------------------------------------
# numpy 1.22.4: 61.910045 MB
# ----------------------------------------
# notebook 6.4.4: 36.819817 MB
# ----------------------------------------
# nbformat 5.9.2: 0.415896 MB
# ----------------------------------------
# nbconvert 7.7.3: 0.499246 MB
# ----------------------------------------
# nbclient 0.5.4: 0.275604 MB
# ----------------------------------------
# nbclassic 0.3.4: 0.103515 MB
# ----------------------------------------
# mistune 3.0.1: 0.253877 MB
# ----------------------------------------
# matplotlib 3.7.0: 22.571484 MB
# ----------------------------------------
# MarkupSafe 2.1.2: 0.047694 MB
# ----------------------------------------
# Markdown 3.4.1: 0.486293 MB
# ----------------------------------------
# lxml 4.9.2: 8.976879 MB
# ----------------------------------------
# lab 7.0: 0.258998 MB
# ----------------------------------------
# keras 2.11.0: 11.13324 MB
# ----------------------------------------
# jupyterlab 4.0.4: 14.934618 MB
# ----------------------------------------
# jsonschema 4.18.6: 0.720932 MB
# ----------------------------------------
# json5 0.9.14: 0.135241 MB
# ----------------------------------------
# joblib 1.2.0: 1.4728 MB
# ----------------------------------------
# Jinja2 3.1.2: 0.908663 MB
# ----------------------------------------
# jedi 0.18.0: 4.524042 MB
# ----------------------------------------
# isoduration 20.11.0: 0.034075 MB
# ----------------------------------------
# ipywidgets 7.6.5: 0.597091 MB
# ----------------------------------------
# ipython 7.34.0: 4.357178 MB
# ----------------------------------------
# ipykernel 6.4.1: 0.652161 MB
# ----------------------------------------
# inflection 0.5.1: 0.02245 MB
# ----------------------------------------
# idna 3.3: 0.459048 MB
# ----------------------------------------
# h5py 3.8.0: 7.176234 MB
# ----------------------------------------
# greenlet 1.1.2: 0.325988 MB
# ----------------------------------------
# gast 0.4.0: 0.073848 MB
# ----------------------------------------
# fqdn 1.5.1: 0.010262 MB
# ----------------------------------------
# fonttools 4.28.5: 5.602677 MB
# ----------------------------------------
# flatbuffers 23.1.21: 0.174523 MB
# ----------------------------------------
# fastjsonschema 2.18.0: 0.138724 MB
# ----------------------------------------
# executing 1.2.0: 0.115217 MB
# ----------------------------------------
# exceptiongroup 1.1.2: 0.057786 MB
# ----------------------------------------
# eod 0.2.1: 0.11069 MB
# ----------------------------------------
# defusedxml 0.7.1: 0.06211 MB
# ----------------------------------------
# debugpy 1.5.0: 25.340877 MB
# ----------------------------------------
# contourpy 1.0.7: 0.438876 MB
# ----------------------------------------
# config 0.5.1: 0.127576 MB
# ----------------------------------------
# colorama 0.4.4: 0.048662 MB
# ----------------------------------------
# cffi 1.15.0: 0.631637 MB
# ----------------------------------------
# certifi 2021.10.8: 0.270431 MB
# ----------------------------------------
# cachetools 5.3.0: 0.062537 MB
# ----------------------------------------
# bleach 6.0.0: 1.058347 MB
# ----------------------------------------
# backcall 0.2.0: 0.054667 MB
# ----------------------------------------
# Babel 2.12.1: 32.207052 MB
# ----------------------------------------
# attrs 23.1.0: 0.005632 MB
# ----------------------------------------
# astunparse 1.6.3: 0.061794 MB
# ----------------------------------------
# asttokens 2.2.1: 0.10434 MB
# ----------------------------------------
# arrow 1.2.3: 0.461673 MB
# ----------------------------------------
# anyio 3.7.1: 0.578032 MB
# ----------------------------------------
